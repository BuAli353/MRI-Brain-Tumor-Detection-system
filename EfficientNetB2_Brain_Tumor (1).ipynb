# %% [markdown]
# # 🧠 Brain Tumor Classification using EfficientNetB2
#
# This notebook classifies brain MRI images into **4 categories**:
# - Glioma
# - Meningioma
# - No Tumor
# - Pituitary
#
# Using **EfficientNetB2** (transfer learning from ImageNet) with a two-phase training strategy.

# %% [markdown]
# ## 1. Important Libraries

# %%
# Check GPU first
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
print("GPU Available:", tf.config.list_physical_devices('GPU'))

if tf.config.list_physical_devices('GPU'):
    print("GPU Name:", tf.config.list_physical_devices('GPU')[0].name)
else:
    print("⚠  No GPU detected — training will be very slow!")
# Out:
# TensorFlow version: 2.19.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU Name: /physical_device:GPU:0

# %%
# Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import shutil
import random
import math

# sklearn packages
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report

# keras / tensorflow packages
import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.applications import EfficientNetB2
from keras.applications.efficientnet import preprocess_input as efficientnet_preprocess
from keras import layers
from keras.models import Model, Sequential
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization

# %% [markdown]
# ## 2. Download & Setup Dataset

# %%
# Upload your kaggle.json to Colab first, then run this cell

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d masoudnickparvar/brain-tumor-mri-dataset
# !unzip -q brain-tumor-mri-dataset.zip -d brain_tumor_data

print("\n✅ Dataset downloaded and extracted!")
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Dataset URL: https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# Downloading brain-tumor-mri-dataset.zip to /content
# 100% 157M/157M [00:01<00:00, 132MB/s]
#
#
# ✅ Dataset downloaded and extracted!

# %%
# Set dataset paths
TRAIN_DIR = 'brain_tumor_data/Training'
TEST_DIR  = 'brain_tumor_data/Testing'

IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 50

# Verify the dataset structure
print("Training classes:", os.listdir(TRAIN_DIR))
print("Testing classes:", os.listdir(TEST_DIR))

# Count images per class
print("\n--- Training Set ---")
total_train = 0
for cls in sorted(os.listdir(TRAIN_DIR)):
    cls_path = os.path.join(TRAIN_DIR, cls)
    if os.path.isdir(cls_path):
        count = len(os.listdir(cls_path))
        total_train += count
        print(f"  {cls}: {count} images")
print(f"  Total: {total_train} images")

print("\n--- Testing Set ---")
total_test = 0
for cls in sorted(os.listdir(TEST_DIR)):
    cls_path = os.path.join(TEST_DIR, cls)
    if os.path.isdir(cls_path):
        count = len(os.listdir(cls_path))
        total_test += count
        print(f"  {cls}: {count} images")
print(f"  Total: {total_test} images")
# Out:
# Training classes: ['pituitary', 'glioma', 'notumor', 'meningioma']
# Testing classes: ['pituitary', 'glioma', 'notumor', 'meningioma']
#
# --- Training Set ---
#   glioma: 1400 images
#   meningioma: 1400 images
#   notumor: 1400 images
#   pituitary: 1400 images
#   Total: 5600 images
#
# --- Testing Set ---
#   glioma: 400 images
#   meningioma: 400 images
#   notumor: 400 images
#   pituitary: 400 images
#   Total: 1600 images

# %% [markdown]
# ## 3. Preprocess the Data
#
# ### 3.1 Check Image Size Distribution
#
# Before resizing all images, let's check the original image dimensions across the dataset.

# %%
# Check the distribution of image sizes in the training and test sets
train_heights = []
train_widths = []
test_heights = []
test_widths = []

# Scan training images
for root, _, files in os.walk(TRAIN_DIR):
    for file in files:
        if file.startswith('.'):
            continue
        img_path = os.path.join(root, file)
        img = cv2.imread(img_path)
        if img is not None:
            h, w = img.shape[:2]
            train_heights.append(h)
            train_widths.append(w)

# Scan testing images
for root, _, files in os.walk(TEST_DIR):
    for file in files:
        if file.startswith('.'):
            continue
        img_path = os.path.join(root, file)
        img = cv2.imread(img_path)
        if img is not None:
            h, w = img.shape[:2]
            test_heights.append(h)
            test_widths.append(w)

print(f"Training images scanned: {len(train_heights)}")
print(f"Testing images scanned:  {len(test_heights)}")
# Out:
# Training images scanned: 5600
# Testing images scanned:  1600

# %%
# Plot image size distributions as scatter plots
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Training set
axes[0].scatter(train_widths, train_heights, alpha=0.3, color='#4ECDC4', edgecolors='none', s=20)
axes[0].set_title('Training Set — Image Size Distribution', fontsize=13, fontweight='bold')
axes[0].set_xlabel('Width (pixels)')
axes[0].set_ylabel('Height (pixels)')
axes[0].grid(True, alpha=0.3)

# Test set
axes[1].scatter(test_widths, test_heights, alpha=0.3, color='#FF6B6B', edgecolors='none', s=20)
axes[1].set_title('Testing Set — Image Size Distribution', fontsize=13, fontweight='bold')
axes[1].set_xlabel('Width (pixels)')
axes[1].set_ylabel('Height (pixels)')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Print stats
print(f"\nTraining — Width:  min={min(train_widths)}, max={max(train_widths)}, mean={np.mean(train_widths):.0f}")
print(f"Training — Height: min={min(train_heights)}, max={max(train_heights)}, mean={np.mean(train_heights):.0f}")
print(f"Testing  — Width:  min={min(test_widths)}, max={max(test_widths)}, mean={np.mean(test_widths):.0f}")
print(f"Testing  — Height: min={min(test_heights)}, max={max(test_heights)}, mean={np.mean(test_heights):.0f}")
print(f"\n→ All images will be resized to {IMG_SIZE} for the model.")
# Out:
# Training — Width:  min=150, max=1375, mean=459
# Training — Height: min=168, max=1446, mean=462
# Testing  — Width:  min=150, max=1149, mean=435
# Testing  — Height: min=167, max=1019, mean=438
#
# → All images will be resized to (224, 224) for the model.

# %% [markdown]
# ### 3.2 Load Raw Images & Inspect Shapes
#
# Load a sample of images to verify pixel values, channels, and shapes before passing them to the model.

# %%
# Load sample images from each class to inspect
sample_images = []
sample_labels = []

for cls in sorted(os.listdir(TRAIN_DIR)):
    cls_path = os.path.join(TRAIN_DIR, cls)
    if not os.path.isdir(cls_path):
        continue
    files = os.listdir(cls_path)
    # Pick 3 random samples from each class
    for fname in random.sample(files, min(3, len(files))):
        img_path = os.path.join(cls_path, fname)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img_resized = cv2.resize(img, IMG_SIZE)
            sample_images.append(img_resized)
            sample_labels.append(cls)

sample_images = np.array(sample_images)

print(f"Loaded {len(sample_images)} sample images")
print(f"Shape of sample array: {sample_images.shape}")
print(f"Pixel value range: [{sample_images.min()}, {sample_images.max()}]")
print(f"Data type: {sample_images.dtype}")
print(f"Single image shape: {sample_images[0].shape}")
# Out:
# Loaded 12 sample images
# Shape of sample array: (12, 224, 224, 3)
# Pixel value range: [0, 255]
# Data type: uint8
# Single image shape: (224, 224, 3)

# %% [markdown]
# ### 3.3 Check for Corrupted / Invalid Images

# %%
# Scan for corrupted images that OpenCV cannot read
corrupted_files = []
grayscale_files = []
total_checked = 0

for split_name, split_dir in [('Training', TRAIN_DIR), ('Testing', TEST_DIR)]:
    for root, _, files in os.walk(split_dir):
        for fname in files:
            if fname.startswith('.'):
                continue
            total_checked += 1
            fpath = os.path.join(root, fname)
            img = cv2.imread(fpath)
            if img is None:
                corrupted_files.append(fpath)
            elif len(img.shape) == 2 or img.shape[2] == 1:
                grayscale_files.append(fpath)

print(f"Total images checked: {total_checked}")
print(f"Corrupted images:     {len(corrupted_files)}")
print(f"Grayscale images:     {len(grayscale_files)}")

if corrupted_files:
    print("\n⚠ Corrupted files:")
    for f in corrupted_files[:10]:
        print(f"  {f}")
else:
    print("\n✅ No corrupted images found!")

if grayscale_files:
    print(f"\nℹ  {len(grayscale_files)} grayscale images found (will be converted to RGB by the generator)")
# Out:
# Total images checked: 7200
# Corrupted images:     0
# Grayscale images:     0
#
# ✅ No corrupted images found!

# %% [markdown]
# ## 4. Distribution of Classes & Sample Images

# %%
# Count samples per class in Training set
train_class_counts = {}
for cls in sorted(os.listdir(TRAIN_DIR)):
    cls_path = os.path.join(TRAIN_DIR, cls)
    if os.path.isdir(cls_path):
        train_class_counts[cls] = len(os.listdir(cls_path))

# Count samples per class in Testing set
test_class_counts = {}
for cls in sorted(os.listdir(TEST_DIR)):
    cls_path = os.path.join(TEST_DIR, cls)
    if os.path.isdir(cls_path):
        test_class_counts[cls] = len(os.listdir(cls_path))

# Plot side by side
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4']

# Training distribution
bars1 = axes[0].bar(train_class_counts.keys(), train_class_counts.values(), color=colors)
axes[0].set_title('Training Set — Class Distribution', fontsize=13, fontweight='bold')
axes[0].set_xlabel('Class')
axes[0].set_ylabel('Number of Images')
for bar, count in zip(bars1, train_class_counts.values()):
    axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + 5,
                 str(count), ha='center', va='bottom', fontsize=11)

# Testing distribution
bars2 = axes[1].bar(test_class_counts.keys(), test_class_counts.values(), color=colors)
axes[1].set_title('Testing Set — Class Distribution', fontsize=13, fontweight='bold')
axes[1].set_xlabel('Class')
axes[1].set_ylabel('Number of Images')
for bar, count in zip(bars2, test_class_counts.values()):
    axes[1].text(bar.get_x() + bar.get_width()/2., bar.get_height() + 5,
                 str(count), ha='center', va='bottom', fontsize=11)

plt.tight_layout()
plt.show()

# %%
# Plot sample images from each class
classes = sorted(os.listdir(TRAIN_DIR))
num_classes = len(classes)
samples_per_class = 3

fig, axes = plt.subplots(num_classes, samples_per_class, figsize=(12, 3 * num_classes))

for row, cls in enumerate(classes):
    cls_path = os.path.join(TRAIN_DIR, cls)
    all_files = os.listdir(cls_path)
    chosen = random.sample(all_files, min(samples_per_class, len(all_files)))

    for col, fname in enumerate(chosen):
        img_path = os.path.join(cls_path, fname)
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        axes[row][col].imshow(img)
        axes[row][col].set_title(f"{cls} ({img.shape[1]}x{img.shape[0]})", fontsize=10)
        axes[row][col].axis('off')

plt.suptitle('Sample Images from Each Class (Original Size)', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Data Augmentation
#
# Data augmentation is a technique in machine learning used to artificially increase the size and diversity of a training dataset by creating modified versions of existing data.
#
# Instead of collecting new data (which is expensive and time-consuming), we apply **transformations** to the current data to teach the model that the core features remain the same even if the appearance changes.
#
# **Why It Matters:**
# - **Prevents Overfitting:** It stops the model from "memorizing" specific training examples.
# - **Improves Generalization:** It helps the model perform better on new, unseen data by exposing it to more variations.
# - **Cost-Effective:** We get a larger dataset for "free" without manual labeling.
#
# **Important Note about EfficientNet:**
# > EfficientNet has its own built-in preprocessing/normalization. We must use `efficientnet_preprocess` instead of `rescale=1./255`. Using `rescale=1./255` would **double-scale** the data (scaling to [0,1] and then EfficientNet scales again internally), which destroys model accuracy.

# %%
# Visualize what data augmentation looks like on a sample image

# Pick a random training image
sample_cls = random.choice(sorted(os.listdir(TRAIN_DIR)))
sample_cls_path = os.path.join(TRAIN_DIR, sample_cls)
sample_fname = random.choice(os.listdir(sample_cls_path))
sample_img = cv2.imread(os.path.join(sample_cls_path, sample_fname))
sample_img = cv2.cvtColor(sample_img, cv2.COLOR_BGR2RGB)
sample_img = cv2.resize(sample_img, IMG_SIZE)

# Create a temporary augmentation generator (without preprocessing for visualization)
aug_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1,
    brightness_range=(0.8, 1.2),
    fill_mode='nearest'
)

# Generate augmented versions
sample_batch = np.expand_dims(sample_img, axis=0)
aug_iter = aug_datagen.flow(sample_batch, batch_size=1)

# Plot original + 7 augmented versions
plt.figure(figsize=(16, 4))

plt.subplot(1, 8, 1)
plt.imshow(sample_img)
plt.title(f'Original\n({sample_cls})', fontsize=9)
plt.axis('off')

for i in range(7):
    aug_img = next(aug_iter)[0].astype(np.uint8)
    plt.subplot(1, 8, i + 2)
    plt.imshow(aug_img)
    plt.title(f'Augmented {i+1}', fontsize=9)
    plt.axis('off')

plt.suptitle('Data Augmentation Examples', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Create the actual data generators for training

# Training data generator with augmentation + EfficientNet preprocessing
train_datagen = ImageDataGenerator(
    preprocessing_function=efficientnet_preprocess,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1,
    validation_split=0.2
)

# Validation/Test generator — NO augmentation, only EfficientNet preprocessing
val_test_datagen = ImageDataGenerator(
    preprocessing_function=efficientnet_preprocess
)

# Training split (80% of Training folder)
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=42
)

# Validation split (20% of Training folder)
val_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',
    shuffle=False,
    seed=42
)

# Test set (separate Testing folder)
test_generator = val_test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Get class names from generator (correct order guaranteed)
class_indices = train_generator.class_indices
class_names = {v: k for k, v in class_indices.items()}
NUM_CLASSES = len(class_names)

print(f"\nClass mapping    : {class_indices}")
print(f"Training samples : {train_generator.samples}")
print(f"Validation samples: {val_generator.samples}")
print(f"Test samples     : {test_generator.samples}")
print(f"Number of classes: {NUM_CLASSES}")
# Out:
# Found 4480 images belonging to 4 classes.
# Found 1120 images belonging to 4 classes.
# Found 1600 images belonging to 4 classes.
#
# Class mapping    : {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}
# Training samples : 4480
# Validation samples: 1120
# Test samples     : 1600
# Number of classes: 4

# %%
# Visualize a batch from the training generator (after preprocessing)
images, labels = next(train_generator)
n_samples = min(8, len(images))

plt.figure(figsize=(12, 6))
for i in range(n_samples):
    plt.subplot(2, 4, i + 1)
    # Undo EfficientNet preprocessing for display
    img = images[i].copy()
    img = (img - img.min()) / (img.max() - img.min() + 1e-8)
    plt.imshow(img)
    label_idx = np.argmax(labels[i])
    plt.title(class_names[label_idx], fontsize=10)
    plt.axis('off')

plt.suptitle('Training Batch — After Augmentation & Preprocessing', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# Print the preprocessed pixel value range
print(f"Preprocessed pixel range: [{images.min():.2f}, {images.max():.2f}]")
print(f"Batch shape: {images.shape}")
print(f"Labels shape: {labels.shape}")
# Out:
# Preprocessed pixel range: [0.00, 255.00]
# Batch shape: (32, 224, 224, 3)
# Labels shape: (32, 4)

# %% [markdown]
# ## 6. Model Building — EfficientNetB2

# %%
# Load the pre-trained EfficientNetB2 base model
eff_base_model = EfficientNetB2(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

# Freeze ALL base model layers initially
# We don't want to ruin the pre-trained weights during initial training
eff_base_model.trainable = False

# Build custom classifier head on top
eff_model = Sequential([
    keras.Input(shape=(224, 224, 3)),
    eff_base_model,
    GlobalAveragePooling2D(),
    BatchNormalization(),
    Dropout(0.3),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(NUM_CLASSES, activation='softmax')
])

eff_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31790344/31790344 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb2 (Functional)     │ (None, 7, 7, 1408)     │     7,768,569 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1408)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1408)           │         5,632 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1408)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       360,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,136,957 (31.04 MB)
#  Trainable params: 365,060 (1.39 MB)
#  Non-trainable params: 7,771,897 (29.65 MB)

# %%
# Print all layers in the EfficientNetB2 base model
# (useful for finding the last conv layer name for Grad-CAM later)
print(f"Total layers in EfficientNetB2: {len(eff_base_model.layers)}")
print("\nLast 20 layers:")
for layer in eff_base_model.layers[-20:]:
    print(f"  {layer.name:40s} | {layer.__class__.__name__:25s} | trainable={layer.trainable}")
# Out:
# Total layers in EfficientNetB2: 340
#
# Last 20 layers:
#   block7a_project_conv                     | Conv2D                    | trainable=False
#   block7a_project_bn                       | BatchNormalization        | trainable=False
#   block7b_expand_conv                      | Conv2D                    | trainable=False
#   block7b_expand_bn                        | BatchNormalization        | trainable=False
#   block7b_expand_activation                | Activation                | trainable=False
#   block7b_dwconv                           | DepthwiseConv2D           | trainable=False
#   block7b_bn                               | BatchNormalization        | trainable=False
#   block7b_activation                       | Activation                | trainable=False
#   block7b_se_squeeze                       | GlobalAveragePooling2D    | trainable=False
#   block7b_se_reshape                       | Reshape                   | trainable=False
#   block7b_se_reduce                        | Conv2D                    | trainable=False
#   block7b_se_expand                        | Conv2D                    | trainable=False
#   block7b_se_excite                        | Multiply                  | trainable=False
#   block7b_project_conv                     | Conv2D                    | trainable=False
#   block7b_project_bn                       | BatchNormalization        | trainable=False
#   block7b_drop                             | Dropout                   | trainable=False
#   block7b_add                              | Add                       | trainable=False
#   top_conv                                 | Conv2D                    | trainable=False
#   top_bn                                   | BatchNormalization        | trainable=False
#   top_activation                           | Activation                | trainable=False

# %% [markdown]
# ## 7. Model Training
#
# ### 7.1 Compile the Model

# %%
eff_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("✅ Model compiled!")
print(f"Optimizer: Adam (lr=1e-4)")
print(f"Loss: categorical_crossentropy")
print(f"Metrics: accuracy")
# Out:
# ✅ Model compiled!
# Optimizer: Adam (lr=1e-4)
# Loss: categorical_crossentropy
# Metrics: accuracy

# %%
# Setup callbacks
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

checkpoint = ModelCheckpoint(
    'best_brain_tumor_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

print("✅ Callbacks ready!")
# Out:
# ✅ Callbacks ready!

# %% [markdown]
# ### 7.2 Phase 1 — Train Classification Head (Base Frozen)
#
# In this phase, all EfficientNetB2 layers are frozen. Only the custom classification head trains on the brain tumor data.

# %%
print("="*60)
print("  Phase 1: Training classification head (base frozen)")
print("="*60)

history = eff_model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    callbacks=[early_stopping, reduce_lr, checkpoint],
    verbose=1
)
# Out:
# ============================================================
#   Phase 1: Training classification head (base frozen)
# ============================================================
# Epoch 1/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.4495 - loss: 1.5923
# Epoch 1: val_accuracy improved from None to 0.79643, saving model to best_brain_tumor_model.keras
#
# Epoch 1: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 132s 628ms/step - accuracy: 0.5469 - loss: 1.3081 - val_accuracy: 0.7964 - val_loss: 0.6165 - learning_rate: 1.0000e-04
# Epoch 2/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.6972 - loss: 0.8462
# Epoch 2: val_accuracy improved from 0.79643 to 0.85000, saving model to best_brain_tumor_model.keras
#
# Epoch 2: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 101s 545ms/step - accuracy: 0.7123 - loss: 0.8083 - val_accuracy: 0.8500 - val_loss: 0.4405 - learning_rate: 1.0000e-04
# Epoch 3/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.7485 - loss: 0.7110
# Epoch 3: val_accuracy improved from 0.85000 to 0.85625, saving model to best_brain_tumor_model.keras
#
# Epoch 3: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 536ms/step - accuracy: 0.7576 - loss: 0.6910 - val_accuracy: 0.8562 - val_loss: 0.3656 - learning_rate: 1.0000e-04
# Epoch 4/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.7648 - loss: 0.6574
# Epoch 4: val_accuracy improved from 0.85625 to 0.87143, saving model to best_brain_tumor_model.keras
#
# Epoch 4: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 531ms/step - accuracy: 0.7739 - loss: 0.6538 - val_accuracy: 0.8714 - val_loss: 0.3418 - learning_rate: 1.0000e-04
# Epoch 5/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.7920 - loss: 0.5986
# Epoch 5: val_accuracy improved from 0.87143 to 0.88661, saving model to best_brain_tumor_model.keras
#
# Epoch 5: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 539ms/step - accuracy: 0.7937 - loss: 0.5729 - val_accuracy: 0.8866 - val_loss: 0.3231 - learning_rate: 1.0000e-04
# Epoch 6/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.8130 - loss: 0.5028
# Epoch 6: val_accuracy improved from 0.88661 to 0.89643, saving model to best_brain_tumor_model.keras
#
# Epoch 6: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 535ms/step - accuracy: 0.8165 - loss: 0.5153 - val_accuracy: 0.8964 - val_loss: 0.2938 - learning_rate: 1.0000e-04
# Epoch 7/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.8191 - loss: 0.4820
# Epoch 7: val_accuracy did not improve from 0.89643
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 526ms/step - accuracy: 0.8174 - loss: 0.4938 - val_accuracy: 0.8893 - val_loss: 0.2897 - learning_rate: 1.0000e-04
# Epoch 8/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.8234 - loss: 0.4905
# Epoch 8: val_accuracy improved from 0.89643 to 0.90268, saving model to best_brain_tumor_model.keras
#
# Epoch 8: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 534ms/step - accuracy: 0.8237 - loss: 0.4872 - val_accuracy: 0.9027 - val_loss: 0.2867 - learning_rate: 1.0000e-04
# Epoch 9/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.8206 - loss: 0.4957
# Epoch 9: val_accuracy improved from 0.90268 to 0.90893, saving model to best_brain_tumor_model.keras
#
# Epoch 9: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 76s 542ms/step - accuracy: 0.8310 - loss: 0.4659 - val_accuracy: 0.9089 - val_loss: 0.2748 - learning_rate: 1.0000e-04
# Epoch 10/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.8281 - loss: 0.4769
# Epoch 10: val_accuracy did not improve from 0.90893
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 536ms/step - accuracy: 0.8335 - loss: 0.4671 - val_accuracy: 0.9071 - val_loss: 0.2810 - learning_rate: 1.0000e-04
# Epoch 11/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.8320 - loss: 0.4368
# Epoch 11: val_accuracy did not improve from 0.90893
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 531ms/step - accuracy: 0.8375 - loss: 0.4369 - val_accuracy: 0.9000 - val_loss: 0.2706 - learning_rate: 1.0000e-04
# Epoch 12/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.8353 - loss: 0.4278
# Epoch 12: val_accuracy did not improve from 0.90893
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 537ms/step - accuracy: 0.8446 - loss: 0.4150 - val_accuracy: 0.9071 - val_loss: 0.2594 - learning_rate: 1.0000e-04
# Epoch 13/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.8506 - loss: 0.3905
# Epoch 13: val_accuracy improved from 0.90893 to 0.91607, saving model to best_brain_tumor_model.keras
#
# Epoch 13: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 76s 546ms/step - accuracy: 0.8533 - loss: 0.3895 - val_accuracy: 0.9161 - val_loss: 0.2498 - learning_rate: 1.0000e-04
# Epoch 14/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.8557 - loss: 0.3842
# Epoch 14: val_accuracy did not improve from 0.91607
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 76s 544ms/step - accuracy: 0.8527 - loss: 0.3974 - val_accuracy: 0.9098 - val_loss: 0.2568 - learning_rate: 1.0000e-04
# Epoch 15/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.8422 - loss: 0.4034
# Epoch 15: val_accuracy improved from 0.91607 to 0.92054, saving model to best_brain_tumor_model.keras
#
# Epoch 15: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 76s 544ms/step - accuracy: 0.8520 - loss: 0.3890 - val_accuracy: 0.9205 - val_loss: 0.2430 - learning_rate: 1.0000e-04
# Epoch 16/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.8521 - loss: 0.4127
# Epoch 16: val_accuracy did not improve from 0.92054
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 532ms/step - accuracy: 0.8538 - loss: 0.3925 - val_accuracy: 0.9125 - val_loss: 0.2427 - learning_rate: 1.0000e-04
# Epoch 17/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.8539 - loss: 0.3684
# Epoch 17: val_accuracy did not improve from 0.92054
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 72s 515ms/step - accuracy: 0.8554 - loss: 0.3722 - val_accuracy: 0.9170 - val_loss: 0.2376 - learning_rate: 1.0000e-04
# Epoch 18/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.8714 - loss: 0.3528
# Epoch 18: val_accuracy did not improve from 0.92054
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 71s 504ms/step - accuracy: 0.8692 - loss: 0.3548 - val_accuracy: 0.9170 - val_loss: 0.2409 - learning_rate: 1.0000e-04
# Epoch 19/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.8677 - loss: 0.3501
# Epoch 19: val_accuracy improved from 0.92054 to 0.92411, saving model to best_brain_tumor_model.keras
#
# Epoch 19: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 73s 519ms/step - accuracy: 0.8643 - loss: 0.3553 - val_accuracy: 0.9241 - val_loss: 0.2307 - learning_rate: 1.0000e-04
# Epoch 20/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8700 - loss: 0.3520
# Epoch 20: val_accuracy improved from 0.92411 to 0.92768, saving model to best_brain_tumor_model.keras
#
# Epoch 20: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 73s 519ms/step - accuracy: 0.8719 - loss: 0.3487 - val_accuracy: 0.9277 - val_loss: 0.2156 - learning_rate: 1.0000e-04
# Epoch 21/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.8741 - loss: 0.3279
# Epoch 21: val_accuracy did not improve from 0.92768
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 528ms/step - accuracy: 0.8699 - loss: 0.3359 - val_accuracy: 0.9143 - val_loss: 0.2310 - learning_rate: 1.0000e-04
# Epoch 22/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.8857 - loss: 0.3148
# Epoch 22: val_accuracy did not improve from 0.92768
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 71s 505ms/step - accuracy: 0.8817 - loss: 0.3206 - val_accuracy: 0.9268 - val_loss: 0.2262 - learning_rate: 1.0000e-04
# Epoch 23/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.8797 - loss: 0.3211
# Epoch 23: val_accuracy did not improve from 0.92768
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 70s 502ms/step - accuracy: 0.8801 - loss: 0.3240 - val_accuracy: 0.9223 - val_loss: 0.2214 - learning_rate: 1.0000e-04
# Epoch 24/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.8801 - loss: 0.3137
# Epoch 24: val_accuracy improved from 0.92768 to 0.93304, saving model to best_brain_tumor_model.keras
#
# Epoch 24: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 73s 519ms/step - accuracy: 0.8737 - loss: 0.3306 - val_accuracy: 0.9330 - val_loss: 0.2091 - learning_rate: 1.0000e-04
# Epoch 25/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.8734 - loss: 0.3471
# Epoch 25: val_accuracy did not improve from 0.93304
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 527ms/step - accuracy: 0.8824 - loss: 0.3232 - val_accuracy: 0.9232 - val_loss: 0.2188 - learning_rate: 1.0000e-04
# Epoch 26/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.8732 - loss: 0.3186
# Epoch 26: val_accuracy did not improve from 0.93304
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 70s 502ms/step - accuracy: 0.8799 - loss: 0.3111 - val_accuracy: 0.9223 - val_loss: 0.2222 - learning_rate: 1.0000e-04
# Epoch 27/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.8892 - loss: 0.3091
# Epoch 27: val_accuracy improved from 0.93304 to 0.93571, saving model to best_brain_tumor_model.keras
#
# Epoch 27: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 73s 522ms/step - accuracy: 0.8839 - loss: 0.3104 - val_accuracy: 0.9357 - val_loss: 0.2098 - learning_rate: 1.0000e-04
# Epoch 28/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.8998 - loss: 0.2838
# Epoch 28: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 532ms/step - accuracy: 0.8926 - loss: 0.2957 - val_accuracy: 0.9304 - val_loss: 0.2054 - learning_rate: 1.0000e-04
# Epoch 29/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.8864 - loss: 0.3022
# Epoch 29: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 529ms/step - accuracy: 0.8855 - loss: 0.3004 - val_accuracy: 0.9241 - val_loss: 0.1978 - learning_rate: 1.0000e-04
# Epoch 30/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.8975 - loss: 0.2788
# Epoch 30: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 73s 522ms/step - accuracy: 0.8924 - loss: 0.2906 - val_accuracy: 0.9250 - val_loss: 0.2119 - learning_rate: 1.0000e-04
# Epoch 31/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.8843 - loss: 0.3012
# Epoch 31: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 535ms/step - accuracy: 0.8859 - loss: 0.2928 - val_accuracy: 0.9214 - val_loss: 0.1986 - learning_rate: 1.0000e-04
# Epoch 32/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.9001 - loss: 0.2682
# Epoch 32: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 533ms/step - accuracy: 0.8913 - loss: 0.2906 - val_accuracy: 0.9223 - val_loss: 0.2016 - learning_rate: 1.0000e-04
# Epoch 33/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.8949 - loss: 0.3020
# Epoch 33: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 533ms/step - accuracy: 0.8940 - loss: 0.2977 - val_accuracy: 0.9250 - val_loss: 0.2094 - learning_rate: 1.0000e-04
# Epoch 34/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.8998 - loss: 0.2819
# Epoch 34: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 34: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 73s 525ms/step - accuracy: 0.8962 - loss: 0.2861 - val_accuracy: 0.9321 - val_loss: 0.2070 - learning_rate: 1.0000e-04
# Epoch 35/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.8933 - loss: 0.2792

# %%
# Find the EfficientNetB2 base model layer
print("All layers in loaded model:")
for i, layer in enumerate(eff_model.layers):
    print(f"  [{i}] {layer.name:40s} | {layer.__class__.__name__}")
# Out:
# All layers in loaded model:
#   [0] efficientnetb2                           | Functional
#   [1] global_average_pooling2d                 | GlobalAveragePooling2D
#   [2] batch_normalization                      | BatchNormalization
#   [3] dropout                                  | Dropout
#   [4] dense                                    | Dense
#   [5] batch_normalization_1                    | BatchNormalization
#   [6] dropout_1                                | Dropout
#   [7] dense_1                                  | Dense

# %%
# Find EfficientNetB2 by type (works regardless of index)
eff_base_model = None
for layer in eff_model.layers:
    if 'efficientnet' in layer.name.lower():
        eff_base_model = layer
        break

if eff_base_model is None:
    # If it's a Functional model, the base layers are directly inside
    eff_base_model = eff_model

print(f"✅ Found base model: {eff_base_model.name}")
print(f"   Total layers: {len(eff_base_model.layers)}")

# Now unfreeze the last 40 layers
eff_base_model.trainable = True
for layer in eff_base_model.layers[:-40]:
    layer.trainable = False

trainable_count = sum(1 for l in eff_base_model.layers if l.trainable)
frozen_count = sum(1 for l in eff_base_model.layers if not l.trainable)
print(f"   Trainable layers: {trainable_count}")
print(f"   Frozen layers:    {frozen_count}")

# Re-compile
eff_model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
print("✅ Model compiled for fine-tuning!")
# Out:
# ✅ Found base model: efficientnetb2
#    Total layers: 340
#    Trainable layers: 40
#    Frozen layers:    300
# ✅ Model compiled for fine-tuning!

# %% [markdown]
# ### 7.3 Phase 1 — Training Curves

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Accuracy
axes[0].plot(history.history['accuracy'], label='Train Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Val Accuracy')
axes[0].set_title('Phase 1 — Accuracy', fontsize=13, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Loss
axes[1].plot(history.history['loss'], label='Train Loss')
axes[1].plot(history.history['val_loss'], label='Val Loss')
axes[1].set_title('Phase 1 — Loss', fontsize=13, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Print best values
best_epoch = np.argmax(history.history['val_accuracy'])
print(f"\nBest Epoch: {best_epoch + 1}")
print(f"Best Val Accuracy: {history.history['val_accuracy'][best_epoch]:.4f}")
print(f"Best Val Loss: {history.history['val_loss'][best_epoch]:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4125/2496669830.py in <cell line: 0>()
#       2
#       3 # Accuracy
# ----> 4 axes[0].plot(history.history['accuracy'], label='Train Accuracy')
#       5 axes[0].plot(history.history['val_accuracy'], label='Val Accuracy')
#       6 axes[0].set_title('Phase 1 — Accuracy', fontsize=13, fontweight='bold')
#
# NameError: name 'history' is not defined

# %% [markdown]
# ### 7.4 Phase 2 — Fine-Tune Top Layers
#
# Now we unfreeze the last 40 layers of EfficientNetB2 and train with a much smaller learning rate to avoid catastrophic forgetting.

# %%
print("="*60)
print("  Phase 2: Fine-tuning top base-model layers")
print("="*60)

# Unfreeze the last 40 layers
eff_base_model.trainable = True
for layer in eff_base_model.layers[:-40]:
    layer.trainable = False

# Count trainable vs frozen layers
trainable_count = sum(1 for layer in eff_base_model.layers if layer.trainable)
frozen_count = sum(1 for layer in eff_base_model.layers if not layer.trainable)
print(f"Trainable layers: {trainable_count}")
print(f"Frozen layers:    {frozen_count}")

# Re-compile with smaller learning rate
eff_model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# New callbacks for fine-tuning
fine_tune_early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=3,
    restore_best_weights=True,
    verbose=1
)

fine_tune_reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-8,
    verbose=1
)

FINE_TUNE_EPOCHS = 10

history_fine = eff_model.fit(
    train_generator,
    epochs=FINE_TUNE_EPOCHS,
    validation_data=val_generator,
    callbacks=[fine_tune_early_stopping, fine_tune_reduce_lr, checkpoint],
    verbose=1
)
# Out:
# ============================================================
#   Phase 2: Fine-tuning top base-model layers
# ============================================================
# Trainable layers: 40
# Frozen layers:    300
# Epoch 1/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.8161 - loss: 0.5157
# Epoch 1: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 123s 588ms/step - accuracy: 0.8263 - loss: 0.4749 - val_accuracy: 0.9054 - val_loss: 0.2745 - learning_rate: 1.0000e-05
# Epoch 2/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.8368 - loss: 0.4346
# Epoch 2: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 532ms/step - accuracy: 0.8460 - loss: 0.4209 - val_accuracy: 0.9080 - val_loss: 0.2710 - learning_rate: 1.0000e-05
# Epoch 3/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.8538 - loss: 0.4071
# Epoch 3: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 526ms/step - accuracy: 0.8487 - loss: 0.4115 - val_accuracy: 0.9116 - val_loss: 0.2478 - learning_rate: 1.0000e-05
# Epoch 4/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8519 - loss: 0.3801
# Epoch 4: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 71s 507ms/step - accuracy: 0.8580 - loss: 0.3747 - val_accuracy: 0.9116 - val_loss: 0.2472 - learning_rate: 1.0000e-05
# Epoch 5/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.8628 - loss: 0.3777
# Epoch 5: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 76s 539ms/step - accuracy: 0.8703 - loss: 0.3442 - val_accuracy: 0.9179 - val_loss: 0.2363 - learning_rate: 1.0000e-05
# Epoch 6/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.8716 - loss: 0.3431
# Epoch 6: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 77s 547ms/step - accuracy: 0.8772 - loss: 0.3353 - val_accuracy: 0.9143 - val_loss: 0.2340 - learning_rate: 1.0000e-05
# Epoch 7/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.8824 - loss: 0.3051
# Epoch 7: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 529ms/step - accuracy: 0.8799 - loss: 0.3149 - val_accuracy: 0.9214 - val_loss: 0.2186 - learning_rate: 1.0000e-05
# Epoch 8/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.8921 - loss: 0.3111
# Epoch 8: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 535ms/step - accuracy: 0.8911 - loss: 0.3010 - val_accuracy: 0.9205 - val_loss: 0.2276 - learning_rate: 1.0000e-05
# Epoch 9/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.8839 - loss: 0.2900
# Epoch 9: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 529ms/step - accuracy: 0.8877 - loss: 0.2936 - val_accuracy: 0.9241 - val_loss: 0.2128 - learning_rate: 1.0000e-05
# Epoch 10/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.8919 - loss: 0.2937
# Epoch 10: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 534ms/step - accuracy: 0.8951 - loss: 0.2972 - val_accuracy: 0.9304 - val_loss: 0.1980 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 10.

# %%
# Continue fine-tuning — model is still improving
eff_model.compile(
    optimizer=Adam(learning_rate=3e-5),   # slightly higher LR
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_fine2 = eff_model.fit(
    train_generator,
    epochs=15,
    validation_data=val_generator,
    callbacks=[
        EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True, verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-8, verbose=1),
        checkpoint
    ],
    verbose=1
)
# Out:
# Epoch 1/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.8964 - loss: 0.2740
# Epoch 1: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 134s 622ms/step - accuracy: 0.8969 - loss: 0.2738 - val_accuracy: 0.9312 - val_loss: 0.1933 - learning_rate: 3.0000e-05
# Epoch 2/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.9170 - loss: 0.2313
# Epoch 2: val_accuracy did not improve from 0.93571
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 77s 551ms/step - accuracy: 0.9114 - loss: 0.2282 - val_accuracy: 0.9321 - val_loss: 0.1816 - learning_rate: 3.0000e-05
# Epoch 3/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.9229 - loss: 0.2040
# Epoch 3: val_accuracy improved from 0.93571 to 0.94375, saving model to best_brain_tumor_model.keras
#
# Epoch 3: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 77s 550ms/step - accuracy: 0.9176 - loss: 0.2175 - val_accuracy: 0.9438 - val_loss: 0.1577 - learning_rate: 3.0000e-05
# Epoch 4/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.9200 - loss: 0.2184
# Epoch 4: val_accuracy did not improve from 0.94375
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 76s 540ms/step - accuracy: 0.9217 - loss: 0.2156 - val_accuracy: 0.9438 - val_loss: 0.1577 - learning_rate: 3.0000e-05
# Epoch 5/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.9257 - loss: 0.1937
# Epoch 5: val_accuracy improved from 0.94375 to 0.94643, saving model to best_brain_tumor_model.keras
#
# Epoch 5: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 77s 550ms/step - accuracy: 0.9234 - loss: 0.2005 - val_accuracy: 0.9464 - val_loss: 0.1354 - learning_rate: 3.0000e-05
# Epoch 6/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.9416 - loss: 0.1633
# Epoch 6: val_accuracy did not improve from 0.94643
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 533ms/step - accuracy: 0.9388 - loss: 0.1663 - val_accuracy: 0.9438 - val_loss: 0.1474 - learning_rate: 3.0000e-05
# Epoch 7/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.9391 - loss: 0.1647
# Epoch 7: val_accuracy improved from 0.94643 to 0.95446, saving model to best_brain_tumor_model.keras
#
# Epoch 7: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 77s 545ms/step - accuracy: 0.9373 - loss: 0.1655 - val_accuracy: 0.9545 - val_loss: 0.1319 - learning_rate: 3.0000e-05
# Epoch 8/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.9387 - loss: 0.1550
# Epoch 8: val_accuracy improved from 0.95446 to 0.95536, saving model to best_brain_tumor_model.keras
#
# Epoch 8: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 76s 540ms/step - accuracy: 0.9397 - loss: 0.1501 - val_accuracy: 0.9554 - val_loss: 0.1201 - learning_rate: 3.0000e-05
# Epoch 9/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.9468 - loss: 0.1380
# Epoch 9: val_accuracy did not improve from 0.95536
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 533ms/step - accuracy: 0.9446 - loss: 0.1424 - val_accuracy: 0.9554 - val_loss: 0.1268 - learning_rate: 3.0000e-05
# Epoch 10/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.9546 - loss: 0.1213
# Epoch 10: val_accuracy improved from 0.95536 to 0.95625, saving model to best_brain_tumor_model.keras
#
# Epoch 10: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 77s 548ms/step - accuracy: 0.9502 - loss: 0.1295 - val_accuracy: 0.9563 - val_loss: 0.1110 - learning_rate: 3.0000e-05
# Epoch 11/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.9513 - loss: 0.1333
# Epoch 11: val_accuracy did not improve from 0.95625
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 528ms/step - accuracy: 0.9500 - loss: 0.1378 - val_accuracy: 0.9563 - val_loss: 0.1057 - learning_rate: 3.0000e-05
# Epoch 12/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9571 - loss: 0.1139
# Epoch 12: val_accuracy did not improve from 0.95625
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 72s 514ms/step - accuracy: 0.9520 - loss: 0.1295 - val_accuracy: 0.9563 - val_loss: 0.1238 - learning_rate: 3.0000e-05
# Epoch 13/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.9636 - loss: 0.0975
# Epoch 13: val_accuracy did not improve from 0.95625
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 539ms/step - accuracy: 0.9645 - loss: 0.1008 - val_accuracy: 0.9563 - val_loss: 0.1211 - learning_rate: 3.0000e-05
# Epoch 14/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.9577 - loss: 0.1122
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-05.
#
# Epoch 14: val_accuracy improved from 0.95625 to 0.96429, saving model to best_brain_tumor_model.keras
#
# Epoch 14: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 528ms/step - accuracy: 0.9563 - loss: 0.1194 - val_accuracy: 0.9643 - val_loss: 0.1064 - learning_rate: 3.0000e-05
# Epoch 15/15
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.9665 - loss: 0.0911
# Epoch 15: val_accuracy did not improve from 0.96429
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 536ms/step - accuracy: 0.9663 - loss: 0.0934 - val_accuracy: 0.9607 - val_loss: 0.1077 - learning_rate: 1.5000e-05
# Restoring model weights from the end of the best epoch: 14.

# %%
history_fine3 = eff_model.fit(
    train_generator,
    epochs=10,
    validation_data=val_generator,
    callbacks=[
        EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True, verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-8, verbose=1),
        checkpoint
    ],
    verbose=1
)
# Out:
# Epoch 1/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.9671 - loss: 0.1003
# Epoch 1: val_accuracy improved from 0.96429 to 0.96607, saving model to best_brain_tumor_model.keras
#
# Epoch 1: finished saving model to best_brain_tumor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 82s 585ms/step - accuracy: 0.9656 - loss: 0.1053 - val_accuracy: 0.9661 - val_loss: 0.0823 - learning_rate: 1.5000e-05
# Epoch 2/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.9692 - loss: 0.0873
# Epoch 2: val_accuracy did not improve from 0.96607
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 527ms/step - accuracy: 0.9663 - loss: 0.0981 - val_accuracy: 0.9607 - val_loss: 0.1105 - learning_rate: 1.5000e-05
# Epoch 3/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.9704 - loss: 0.0806
# Epoch 3: val_accuracy did not improve from 0.96607
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 73s 524ms/step - accuracy: 0.9656 - loss: 0.0880 - val_accuracy: 0.9661 - val_loss: 0.1098 - learning_rate: 1.5000e-05
# Epoch 4/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.9657 - loss: 0.0870
# Epoch 4: ReduceLROnPlateau reducing learning rate to 7.499999810534064e-06.
#
# Epoch 4: val_accuracy did not improve from 0.96607
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 535ms/step - accuracy: 0.9661 - loss: 0.0925 - val_accuracy: 0.9616 - val_loss: 0.1143 - learning_rate: 1.5000e-05
# Epoch 5/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.9702 - loss: 0.0832
# Epoch 5: val_accuracy did not improve from 0.96607
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 76s 538ms/step - accuracy: 0.9692 - loss: 0.0903 - val_accuracy: 0.9634 - val_loss: 0.1023 - learning_rate: 7.5000e-06
# Epoch 6/10
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.9692 - loss: 0.0886
# Epoch 6: val_accuracy did not improve from 0.96607
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 75s 540ms/step - accuracy: 0.9712 - loss: 0.0831 - val_accuracy: 0.9598 - val_loss: 0.1073 - learning_rate: 7.5000e-06
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %%
# 1. Save final model
eff_model.save('EfficientNetB2_brain_tumor_model.keras')
print("✅ Final model saved! (Val Accuracy: 96.61%)")
# Out:
# ✅ Final model saved! (Val Accuracy: 96.61%)

# %%
# 2. Test set evaluation
test_loss, test_accuracy = eff_model.evaluate(test_generator, verbose=1)
print(f"\nTest Loss:     {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.9319 - loss: 0.2742
#
# Test Loss:     0.2742
# Test Accuracy: 0.9319

# %%
# 3. Confusion Matrix & Classification Report
predictions = eff_model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes
target_names = [class_names[i] for i in range(NUM_CLASSES)]

# Confusion Matrix
cm = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=target_names, yticklabels=target_names)
plt.title('Confusion Matrix — EfficientNetB2', fontsize=14, fontweight='bold')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()

# Classification Report
print("\nClassification Report:\n")
print(classification_report(true_classes, predicted_classes, target_names=target_names))
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 81ms/step
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       glioma       0.96      0.81      0.87       400
#   meningioma       0.88      0.93      0.91       400
#      notumor       0.94      1.00      0.97       400
#    pituitary       0.96      0.99      0.97       400
#
#     accuracy                           0.93      1600
#    macro avg       0.93      0.93      0.93      1600
# weighted avg       0.93      0.93      0.93      1600

# %% [markdown]
# ### 7.5 Phase 2 — Training Curves

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Accuracy
axes[0].plot(history_fine.history['accuracy'], label='Train Accuracy')
axes[0].plot(history_fine.history['val_accuracy'], label='Val Accuracy')
axes[0].set_title('Phase 2 (Fine-tune) — Accuracy', fontsize=13, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Loss
axes[1].plot(history_fine.history['loss'], label='Train Loss')
axes[1].plot(history_fine.history['val_loss'], label='Val Loss')
axes[1].set_title('Phase 2 (Fine-tune) — Loss', fontsize=13, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Print best values
best_epoch_ft = np.argmax(history_fine.history['val_accuracy'])
print(f"\nBest Epoch: {best_epoch_ft + 1}")
print(f"Best Val Accuracy: {history_fine.history['val_accuracy'][best_epoch_ft]:.4f}")
print(f"Best Val Loss: {history_fine.history['val_loss'][best_epoch_ft]:.4f}")
# Out:
# Best Epoch: 10
# Best Val Accuracy: 0.9304
# Best Val Loss: 0.1980

# %% [markdown]
# ## 8. Evaluation

# %% [markdown]
# ## 10. Grad-CAM Visualization
#
# Grad-CAM (Gradient-weighted Class Activation Mapping) is the "X-ray vision" of Deep Learning models. It highlights which regions of the MRI the model focuses on to make its prediction.
#
# > The **red/yellow** areas in the heatmap show the regions the model considers most important for classification. **Blue** areas have less influence on the prediction.

# %%
# Find the last Conv2D layer name in EfficientNetB2 for Grad-CAM
last_conv_layer = None
for layer in reversed(eff_base_model.layers):
    if isinstance(layer, tf.keras.layers.Conv2D):
        last_conv_layer = layer.name
        break

print(f"Last conv layer for Grad-CAM: {last_conv_layer}")
print(f"Total layers in base model: {len(eff_base_model.layers)}")
# Out:
# Last conv layer for Grad-CAM: top_conv
# Total layers in base model: 340

# %%
base = eff_model.layers[0]  # EfficientNetB2 (Functional — has .input/.output)

# Find last conv layer
last_conv_layer = None
for layer in reversed(base.layers):
    if isinstance(layer, tf.keras.layers.Conv2D):
        last_conv_layer = layer.name
        break
print(f"Last conv layer: {last_conv_layer}")

# Grad model from BASE model only
grad_model = tf.keras.models.Model(
    inputs=base.input,
    outputs=[base.get_layer(last_conv_layer).output, base.output]
)

test_images, test_labels = next(test_generator)
num_display = min(8, len(test_images))

plt.figure(figsize=(16, 4 * math.ceil(num_display / 4)))

for i in range(num_display):
    img = test_images[i]
    img_batch = np.expand_dims(img, axis=0)

    with tf.GradientTape() as tape:
        conv_outputs, base_output = grad_model(img_batch)
        # Manually forward through remaining layers (GAP → Dense → softmax)
        x = base_output
        for layer in eff_model.layers[1:]:
            x = layer(x, training=False)
        preds = x
        pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    grads = tape.gradient(class_channel, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    heatmap = conv_outputs[0] @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / (tf.math.reduce_max(heatmap) + 1e-8)
    heatmap = heatmap.numpy()

    display_img = img.copy()
    display_img = ((display_img - display_img.min()) / (display_img.max() - display_img.min() + 1e-8) * 255).astype(np.uint8)
    heatmap_resized = cv2.resize(heatmap, (display_img.shape[1], display_img.shape[0]))
    heatmap_colored = cv2.applyColorMap(np.uint8(255 * heatmap_resized), cv2.COLORMAP_JET)
    heatmap_colored = cv2.cvtColor(heatmap_colored, cv2.COLOR_BGR2RGB)
    superimposed = cv2.addWeighted(display_img, 0.6, heatmap_colored, 0.4, 0)

    pred_class = int(tf.argmax(preds[0]))
    true_class = np.argmax(test_labels[i])

    plt.subplot(math.ceil(num_display / 4), 4, i + 1)
    plt.imshow(superimposed)
    color = 'green' if pred_class == true_class else 'red'
    plt.title(f"True: {class_names[true_class]}\nPred: {class_names[pred_class]}", fontsize=9, color=color)
    plt.axis('off')

plt.suptitle('Grad-CAM Visualization — EfficientNetB2', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# Last conv layer: top_conv

# %% [markdown]
# ## 11. Save the Trained Model

# %%
eff_model.save('EfficientNetB2_brain_tumor_model.keras')
print("✅ Model saved to: EfficientNetB2_brain_tumor_model.keras")

# %% [markdown]
# ## 12. Download Model (Google Colab)

# %%
from google.colab import files
files.download('EfficientNetB2_brain_tumor_model.keras')
files.download('best_brain_tumor_model.keras')

print("\n✅ All done! Training complete.")
